# %% [markdown]
# # **A01 - Regresión polinomial**
#
# Diana Fernanda Barbosa
#
# Fecha de entrega: Domingo 25 de enero de 2026
#
# 756920
#
# Ingeniería Financiera

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8dbe3547-38b0-43fd-ba91-6a25ee4b5067" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8dbe3547-38b0-43fd-ba91-6a25ee4b5067">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-66b4e65b-a1a5-4e3f-bafa-d3ac26fb31b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66b4e65b-a1a5-4e3f-bafa-d3ac26fb31b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Salarios_minimos = pd.read_csv("Salarios_minimos.csv")

# %%
Bateria_tableta = pd.read_csv("bateria_tableta.txt")

# %% [markdown]
# # **Salarios**

# %% [markdown]
# 1. Revisamos los datos principales de nuestros archivos e identificamos nuestros datos

# %%
Salarios_minimos.head()
# Out:
#    Periodo  Salario
# 0  1988.25     8.00
# 1  1989.00     8.64
# 2  1989.50     9.16
# 3  1990.00    10.08
# 4  1990.84    11.90

# %%
Salarios = Salarios_minimos

# %%
x = Salarios["Periodo"]
x = np.array(x).reshape(-1,1)
x
# Out:
# array([[1988.25],
#        [1989.  ],
#        [1989.5 ],
#        [1990.  ],
#        [1990.84],
#        [1991.84],
#        [1993.  ],
#        [1994.  ],
#        [1995.  ],
#        [1995.3 ],
#        [1996.  ],
#        [1996.3 ],
#        [1997.  ],
#        [1998.  ],
#        [1999.  ],
#        [2000.  ],
#        [2001.  ],
#        [2002.  ],
#        [2003.  ],
#        [2004.  ],
#        [2005.  ],
#        [2006.  ],
#        [2007.  ],
#        [2008.  ],
#        [2009.  ],
#        [2010.  ],
#        [2011.  ],
#        [2012.  ],
#        [2013.  ],
#        [2014.  ],
#        [2015.  ],
#        [2016.  ],
#        [2017.  ],
#        [2018.  ]])

# %%
y = Salarios["Salario"]
y = np.array(y).reshape(-1,1)
y
# Out:
# array([[ 8.  ],
#        [ 8.64],
#        [ 9.16],
#        [10.08],
#        [11.9 ],
#        [13.33],
#        [14.27],
#        [15.27],
#        [16.34],
#        [18.3 ],
#        [20.15],
#        [22.6 ],
#        [26.45],
#        [30.2 ],
#        [34.45],
#        [37.9 ],
#        [40.35],
#        [42.15],
#        [43.65],
#        [45.24],
#        [46.8 ],
#        [48.67],
#        [50.57],
#        [52.59],
#        [54.8 ],
#        [57.46],
#        [59.82],
#        [62.33],
#        [64.76],
#        [67.29],
#        [70.1 ],
#        [73.04],
#        [80.04],
#        [88.36]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([-5022.60217164])

# %%
lr.coef_
# Out:
# array([[2.52832885]])

# %% [markdown]
# Beta 0 = -5022.60
#
# Beta 1 = 2.52
#
# Nuestra mini formula queda: **y = -5022 + 2.52x**

# %% [markdown]
# ## **Bateria**

# %%
Bateria_tableta.head()
# Out:
#    carga  duracion
# 0   2.81      5.62
# 1   7.14      8.00
# 2   2.72      5.44
# 3   3.87      7.74
# 4   1.90      3.80

# %%
Bateria = Bateria_tableta

# %%
x = Bateria["carga"]
x = np.array(x).reshape(-1,1)
x
# Out:
# array([[ 2.81],
#        [ 7.14],
#        [ 2.72],
#        [ 3.87],
#        [ 1.9 ],
#        [ 7.82],
#        [ 7.02],
#        [ 5.5 ],
#        [ 9.15],
#        [ 4.87],
#        [ 8.08],
#        [ 5.58],
#        [ 9.13],
#        [ 0.14],
#        [ 2.  ],
#        [ 5.47],
#        [ 0.8 ],
#        [ 4.37],
#        [ 5.31],
#        [ 0.  ],
#        [ 1.78],
#        [ 3.45],
#        [ 6.13],
#        [ 3.53],
#        [ 4.61],
#        [ 1.76],
#        [ 6.39],
#        [ 0.02],
#        [ 9.69],
#        [ 5.33],
#        [ 6.37],
#        [ 5.55],
#        [ 7.8 ],
#        [ 2.06],
#        [ 7.79],
#        [ 2.24],
#        [ 9.71],
#        [ 1.11],
#        [ 8.38],
#        [ 2.33],
#        [ 1.83],
#        [ 5.94],
#        [ 9.2 ],
#        [ 1.14],
#        [ 4.15],
#        [ 8.43],
#        [ 5.68],
#        [ 8.21],
#        [ 1.75],
#        [ 2.16],
#        [ 4.93],
#        [ 5.75],
#        [ 1.26],
#        [ 3.97],
#        [ 4.39],
# ...

# %%
y = Bateria["duracion"]
y = np.array(y).reshape(-1,1)
y
# Out:
# array([[5.62],
#        [8.  ],
#        [5.44],
#        [7.74],
#        [3.8 ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [0.28],
#        [4.  ],
#        [8.  ],
#        [1.6 ],
#        [8.  ],
#        [8.  ],
#        [0.  ],
#        [3.56],
#        [6.9 ],
#        [8.  ],
#        [7.06],
#        [8.  ],
#        [3.52],
#        [8.  ],
#        [0.04],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [4.12],
#        [8.  ],
#        [4.48],
#        [8.  ],
#        [2.22],
#        [8.  ],
#        [4.66],
#        [3.66],
#        [8.  ],
#        [8.  ],
#        [2.28],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [8.  ],
#        [3.5 ],
#        [4.32],
#        [8.  ],
#        [8.  ],
#        [2.52],
#        [7.94],
#        [8.  ],
#        [8.  ],
#        [3.96],
#        [3.32],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([2.87054111])

# %%
lr.coef_
# Out:
# array([[0.72955585]])

# %% [markdown]
# Beta 0 = 2.87
#
# Beta 1 = 0.72
#
# Nuestra mini formula queda: **y = 2.87 + 0.72x**

# %% [markdown]
# **Regresiones polinomiales de orden 1, 3, 5 y 7.**

# %% [markdown]
# # **Orden 1**

# %%
x = x

# %% [markdown]
# # **Orden 3**

# %%
x2 = x*x

# %%
x3 = x2*x

# %%
X = np.hstack((x,x2,x3))
X
# Out:
# array([[2.81000000e+00, 7.89610000e+00, 2.21880410e+01],
#        [7.14000000e+00, 5.09796000e+01, 3.63994344e+02],
#        [2.72000000e+00, 7.39840000e+00, 2.01236480e+01],
#        [3.87000000e+00, 1.49769000e+01, 5.79606030e+01],
#        [1.90000000e+00, 3.61000000e+00, 6.85900000e+00],
#        [7.82000000e+00, 6.11524000e+01, 4.78211768e+02],
#        [7.02000000e+00, 4.92804000e+01, 3.45948408e+02],
#        [5.50000000e+00, 3.02500000e+01, 1.66375000e+02],
#        [9.15000000e+00, 8.37225000e+01, 7.66060875e+02],
#        [4.87000000e+00, 2.37169000e+01, 1.15501303e+02],
#        [8.08000000e+00, 6.52864000e+01, 5.27514112e+02],
#        [5.58000000e+00, 3.11364000e+01, 1.73741112e+02],
#        [9.13000000e+00, 8.33569000e+01, 7.61048497e+02],
#        [1.40000000e-01, 1.96000000e-02, 2.74400000e-03],
#        [2.00000000e+00, 4.00000000e+00, 8.00000000e+00],
#        [5.47000000e+00, 2.99209000e+01, 1.63667323e+02],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([-0.84459866])

# %%
lr.coef_
# Out:
# array([[ 3.34240792, -0.39326189,  0.01452403]])

# %% [markdown]
# # **Orden 5**

# %%
x = x

# %%
x2 = x*x

# %%
x3 = x2*x

# %%
x5 = x2*x3

# %%
X = np.hstack((x,x2,x3,x5))
X
# Out:
# array([[2.81000000e+00, 7.89610000e+00, 2.21880410e+01, 1.75198991e+02],
#        [7.14000000e+00, 5.09796000e+01, 3.63994344e+02, 1.85562861e+04],
#        [2.72000000e+00, 7.39840000e+00, 2.01236480e+01, 1.48882797e+02],
#        [3.87000000e+00, 1.49769000e+01, 5.79606030e+01, 8.68070155e+02],
#        [1.90000000e+00, 3.61000000e+00, 6.85900000e+00, 2.47609900e+01],
#        [7.82000000e+00, 6.11524000e+01, 4.78211768e+02, 2.92437973e+04],
#        [7.02000000e+00, 4.92804000e+01, 3.45948408e+02, 1.70484759e+04],
#        [5.50000000e+00, 3.02500000e+01, 1.66375000e+02, 5.03284375e+03],
#        [9.15000000e+00, 8.37225000e+01, 7.66060875e+02, 6.41365316e+04],
#        [4.87000000e+00, 2.37169000e+01, 1.15501303e+02, 2.73933285e+03],
#        [8.08000000e+00, 6.52864000e+01, 5.27514112e+02, 3.44394973e+04],
#        [5.58000000e+00, 3.11364000e+01, 1.73741112e+02, 5.40967276e+03],
#        [9.13000000e+00, 8.33569000e+01, 7.61048497e+02, 6.34386435e+04],
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([-0.47144555])

# %%
lr.coef_
# Out:
# array([[ 2.76006152e+00, -1.86466913e-01, -7.03327946e-03,
#          6.13166525e-05]])

# %% [markdown]
# # **Orden 7**

# %%
x = x

# %%
x2 = x*x

# %%
x3 = x2*x

# %%
x5 = x2*x3

# %%
x7 = x5*x2

# %%
X = np.hstack((x,x2,x3,x5,x7))
X
# Out:
# array([[2.81000000e+00, 7.89610000e+00, 2.21880410e+01, 1.75198991e+02,
#         1.38338875e+03],
#        [7.14000000e+00, 5.09796000e+01, 3.63994344e+02, 1.85562861e+04,
#         9.45992041e+05],
#        [2.72000000e+00, 7.39840000e+00, 2.01236480e+01, 1.48882797e+02,
#         1.10149449e+03],
#        [3.87000000e+00, 1.49769000e+01, 5.79606030e+01, 8.68070155e+02,
#         1.30009999e+04],
#        [1.90000000e+00, 3.61000000e+00, 6.85900000e+00, 2.47609900e+01,
#         8.93871739e+01],
#        [7.82000000e+00, 6.11524000e+01, 4.78211768e+02, 2.92437973e+04,
#         1.78832839e+06],
#        [7.02000000e+00, 4.92804000e+01, 3.45948408e+02, 1.70484759e+04,
#         8.40155713e+05],
#        [5.50000000e+00, 3.02500000e+01, 1.66375000e+02, 5.03284375e+03,
#         1.52243523e+05],
#        [9.15000000e+00, 8.37225000e+01, 7.66060875e+02, 6.41365316e+04,
#         5.36967077e+06],
#        [4.87000000e+00, 2.37169000e+01, 1.15501303e+02, 2.73933285e+03,
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# array([-0.00558176])

# %%
lr.coef_
# Out:
# array([[ 1.57451608e+00,  4.44056807e-01, -1.04201655e-01,
#          7.69918344e-04, -2.43792298e-06]])

# %% [markdown]
# # **Modelo de R2**

# %%
R2 = lr.score(X,y)
R2
# Out:
# 0.9938106205015764

# %% [markdown]
# # **Gráfica con una nube de dispersión**

# %%
X = Salarios.iloc[:,0].values.reshape(-1,1)
y = Salarios.iloc[:,1].values

X2 = np.linspace(X.min(), X.max(), 300).reshape(-1,1)

plt.scatter(X, y)

p1 = PolynomialFeatures(1)
m1 = LinearRegression().fit(p1.fit_transform(X), y)
plt.plot(X2, m1.predict(p1.transform(X2)))

p3 = PolynomialFeatures(3)
m3 = LinearRegression().fit(p3.fit_transform(X), y)
plt.plot(X2, m3.predict(p3.transform(X2)))

p5 = PolynomialFeatures(5)
m5 = LinearRegression().fit(p5.fit_transform(X), y)
plt.plot(X2, m5.predict(p5.transform(X2)))

p7 = PolynomialFeatures(7)
m7 = LinearRegression().fit(p7.fit_transform(X), y)
plt.plot(X2, m7.predict(p7.transform(X2)))

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

X = Bateria.iloc[:,0].values.reshape(-1,1)
y = Bateria.iloc[:,1].values

X_plot = np.linspace(X.min(), X.max(), 300).reshape(-1,1)

plt.scatter(X, y)

for g in [1,3,5,7]:
    poly = PolynomialFeatures(g)
    model = LinearRegression().fit(poly.fit_transform(X), y)
    plt.plot(X_plot, model.predict(poly.transform(X_plot)))

plt.show()
